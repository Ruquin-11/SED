# %% [markdown]
# <a href="https://colab.research.google.com/github/Ruquin-11/SED/blob/main/SED.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('/content/spam_ham_dataset.csv')

# %%
print(data)
# Out:
#       Unnamed: 0 label                                               text  \
# 0            605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1           2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2           3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3           4685  spam  Subject: photoshop , windows , office . cheap ...
# 4           2030   ham  Subject: re : indian springs\r\nthis deal is t...
# ...          ...   ...                                                ...
# 5166        1518   ham  Subject: put the 10 on the ft\r\nthe transport...
# 5167         404   ham  Subject: 3 / 4 / 2000 and following noms\r\nhp...
# 5168        2933   ham  Subject: calpine daily gas nomination\r\n>\r\n...
# 5169        1409   ham  Subject: industrial worksheets for august 2000...
# 5170        4807  spam  Subject: important online banking alert\r\ndea...
#
#       label_num
# 0             0
# 1             0
# 2             0
# ...

# %%
data.head()
# Out:
#    Unnamed: 0 label                                               text  \
# 0         605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1        2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2        3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3        4685  spam  Subject: photoshop , windows , office . cheap ...
# 4        2030   ham  Subject: re : indian springs\r\nthis deal is t...
#
#    label_num
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0

# %%
print("number of rows and columns in the given dataset")
print(data.shape)
# Out:
# number of rows and columns in the given dataset
# (5171, 4)

# %%
duplicate = data.duplicated().sum()
print(f'number of duplicated rows are {duplicate}')
# Out:
# number of duplicated rows are 0

# %%
data.drop(columns={'Unnamed: 0'}, inplace=True)

# %%
data.head()
# Out:
#   label                                               text  label_num
# 0   ham  Subject: enron methanol ; meter # : 988291\r\n...          0
# 1   ham  Subject: hpl nom for january 9 , 2001\r\n( see...          0
# 2   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...          0
# 3  spam  Subject: photoshop , windows , office . cheap ...          1
# 4   ham  Subject: re : indian springs\r\nthis deal is t...          0

# %%
X = data['text']
Y = data['label_num']

# %%
print(X)
# Out:
# 0       Subject: enron methanol ; meter # : 988291\r\n...
# 1       Subject: hpl nom for january 9 , 2001\r\n( see...
# 2       Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3       Subject: photoshop , windows , office . cheap ...
# 4       Subject: re : indian springs\r\nthis deal is t...
#                               ...
# 5166    Subject: put the 10 on the ft\r\nthe transport...
# 5167    Subject: 3 / 4 / 2000 and following noms\r\nhp...
# 5168    Subject: calpine daily gas nomination\r\n>\r\n...
# 5169    Subject: industrial worksheets for august 2000...
# 5170    Subject: important online banking alert\r\ndea...
# Name: text, Length: 5171, dtype: object

# %%
print(Y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 5166    0
# 5167    0
# 5168    0
# 5169    0
# 5170    1
# Name: label_num, Length: 5171, dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(data.text,data.label_num,test_size=0.25)

# %%
print(X.shape)
print(X_train.shape)
print(X_test.shape)
# Out:
# (5171,)
# (3878,)
# (1293,)

# %%
 tfidf_vectorizer= TfidfVectorizer(min_df = 1, stop_words='english', lowercase=True)

X_train_vectorized = tfidf_vectorizer.fit_transform(X_train)
X_test_vectorized = tfidf_vectorizer.transform(X_test)

# convert Y_train and Y_test values as integers

Y_train = Y_train.astype('int')
Y_test = Y_test.astype('int')

# %%
print(X_train)
# Out:
# 2454    Subject: re : coastal ctr # 96008903 meter 098...
# 1963    Subject: fw : first delivery - rodessa operati...
# 4444    Subject: re : cornhusker\r\njohn ,\r\ni did so...
# 5092    Subject: eastrans november first of the month ...
# 4785    Subject: something unusual\r\njust her size . ...
#                               ...
# 4583    Subject: hpl nom for dec . 15 , 2000\r\n( see ...
# 973     Subject: pc install p 600\r\ndaren\r\ni ' m wo...
# 2988    Subject: brandywine meter # : 981225 ; march ,...
# 747     Subject: enron / hpl actuals for january 11 , ...
# 1374    Subject: fw : 2 nd rev / hpl nom . eff . march...
# Name: text, Length: 3878, dtype: object

# %%
print(X_test)
# Out:
# 58      Subject: re : nom / actual flow for april 4 th...
# 1167    Subject: hpl nom for may 8 , 2001\r\n( see att...
# 3447                 Subject: re : no more injections\r\n
# 4455    Subject: south hampton refining\r\ni have adde...
# 4095    Subject: equistar 12 / 00\r\n- - - - - - - - -...
#                               ...
# 1027    Subject: lst rev mar . 2000 josey ranch nom\r\...
# 977     Subject: check the superb specials on top - se...
# 4204    Subject: tejas nomination change effective 7 /...
# 2875    Subject: re : deal # 339693 eol waha\r\n- - - ...
# 4678    Subject: volume increase - hpl meter 68 - 6296...
# Name: text, Length: 1293, dtype: object

# %%
model = LogisticRegression()

# %%
model.fit(X_train_vectorized, Y_train)
# Out:
# LogisticRegression()

# %%
prediction_on_training_data = model.predict(X_train_vectorized)
accuracy_on_training_data = accuracy_score(Y_train, prediction_on_training_data)

# %%
print('Accuracy on training data : ', accuracy_on_training_data)
# Out:
# Accuracy on training data :  0.9963898916967509

# %%
prediction_on_test_data = model.predict(X_test_vectorized)
accuracy_on_test_data = accuracy_score(Y_test, prediction_on_test_data)

# %%
print('Accuracy on test data : ', accuracy_on_test_data)
# Out:
# Accuracy on test data :  0.988399071925754

# %%
def predict_email(text):
    vectorized_text = tfidf_vectorizer.transform([text])
    prediction = model.predict(vectorized_text)
    return "Spam" if prediction[0] == 1 else "Ham"

# %%
while True:
    mail = input("Enter email text (or type 'exit' to stop): ")
    if mail.lower() == 'exit':
        print("Exiting prediction.")
        break
    print("Prediction:", predict_email(mail))
# Out:
# Enter email text (or type 'exit' to stop): exit
# Exiting prediction.
